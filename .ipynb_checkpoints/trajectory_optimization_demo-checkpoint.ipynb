# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
from timeit import time
from shape import Shape, Block
from shape_boat import ShapeBoat, ShapeBoat_spline
from shapeshift_trajectory import shapeshift_trajectory, write_experiment
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ### Composing Shapes from Blocks

# %%
shape_1a = Shape([Block(0,0)])
shape_2a = Shape([Block(-.5,0),   Block(.5,0)])
shape_2b = Shape([Block(0,0.25),  Block(0,-0.25)])
shape_3a = Shape([Block(-.5,0),   Block(.5,0),   Block(-1.25,0.25,90)])
shape_3b = Shape([Block(-.5,0),   Block(.5,0,0), Block(-.5,0.5)])
shape_3c = Shape([Block(0,0),     Block(-1,0),   Block(1,0)])
shape_4a = Shape([Block(-.5,0),   Block(.5,0),   Block(-1.25,0.25,90),Block(1.25,0.25,90)])
shape_4b = Shape([Block(-.5,-.25),Block(-.5,.25),Block(.5,-.25),      Block(.5,.25)])
shape_6a = Shape([Block(0,0),     Block(1.,0),   Block(0,0.5),        Block(-1.,0.5),Block(1.,0.5),Block(1.,-.5)])

# %%
moving_shape=shape_3b
obstacle_shape=shape_6a

moving_shape.plot(union=False)
obstacle_shape.plot(union=False)

# %% [markdown]
# ### Partitioning of convex hulls around shape

# %%
msums, hulls = obstacle_shape.c_space_rotate(moving_shape)
#plot_hulls(hulls, text=False)

# %% [markdown]
# ### C-Space of a given obstacle b

# %%
moving_shape.plot_polygons([msums.values()[3]])

# %% [markdown]
# ### Finding Convex Hull of C-Space

# %%
moving_shape.plot_polygons(hulls.values()[3])

# %% [markdown]
# ## Trajectory Planning

# %%
tests = {'line_to_L':         (shape_1a, shape_2a, (-2.5, 0.,   0.),    (-1,     .5,   0.)),  \
         'T_to_block':        (shape_1a, shape_3b, (-1.5, 0.,   0.),    (.5,     .5,   0.)),  \
         'line_to_block':     (shape_2a, shape_2a, (-2.,  0.,   0.),    (0.,     .5,   0.)),  \
         'line_to_L2':        (shape_2a, shape_2a, (-2.,  0.,   0.),    (-1.25, .75,  90.)),  \
         'U_to_block':        (shape_3a, shape_3a, (2.5,  0.,   0.),    (0.,     .5, 180.)),  \
         'line_to_block2':    (shape_4b, shape_4b, (-2.,  0.,   0.),    (0.,     1.,   0.)),  \
         'triangle_to_block': (shape_6a, shape_6a, ( 0.,-0.5, 180.),    (0.,    1.5, 180.)),  \
         'past':              (shape_1a, shape_4a, (-5.,  0.,   0.),    (5.,     0.,   0.))   \
        }

boats = {'line':ShapeBoat, 'spline':ShapeBoat_spline}

# %% [markdown]
# ### MIQP - b-splines

# %%
test = 'triangle_to_block'

x = time.time()
experiment = shapeshift_trajectory(*tests[test], N=11, boat_type_init=ShapeBoat_spline)
# Out:
# finding_vertex POINT (0 -0.5) 180.0
# finding_vertex POINT (0 1.5) 180.0
# found path endpoint hulls 31 32
# INITIALIZED ShapeBoat_spline
# boats_S:(1, 12, 6), boats_U:(1, 11, 4)
# Number of decision vars 204
# 0.002399 seconds
# ADDING COSTS
# Number of costs 13
# 0.004555 seconds
# ADDING CONSTRAINTS
# Number of constraints 1612
# 0.258519 seconds
# PLANNING
# SolutionResult.kSolutionFound
# 0.134820 seconds
#
# finding_vertex POINT (0 -0.5) 180.0
# finding_vertex POINT (0 1.5) 180.0
# found path endpoint hulls 31 32
# INITIALIZED ShapeBoat_spline
# boats_S:(1, 12, 6), boats_U:(1, 11, 4)
# Number of decision vars 116
# 0.000929 seconds
# ADDING COSTS
# Number of costs 13
# 0.004538 seconds
# ADDING CONSTRAINTS
# Number of constraints 594
# 0.176179 seconds
# PLANNING
# SolutionResult.kSolutionFound
# 0.085867 seconds
#
# Time Scaling target: 1.000000, result: 1.000000
# Time Scaling target: 1.456622, result: 1.600000

# %% [markdown]
# ### Show polytope graph from plan

# %%
experiment['boat'].g.draw_graph()

# %% [markdown]
# ### Run Experiments

# %%
def result(test, boat):
    boat_init = boat if boat is ShapeBoat_spline else None
    return shapeshift_trajectory(*tests[test],boat_type=boat, boat_type_init=boat_init, N=11)

results = {boat:{test: result(test, boats[boat]) for test in tests} for boat in boats}
# Out:
# finding_vertex POINT (-5 0) 0.0
# finding_vertex POINT (5 0) 0.0
# found path endpoint hulls 13 8
# INITIALIZED ShapeBoat
# boats_S:(1, 12, 6), boats_U:(1, 11, 4)
# Number of decision vars 149
# 0.001424 seconds
# ADDING COSTS
# Number of costs 2
# 0.001144 seconds
# ADDING CONSTRAINTS
# Number of constraints 436
# 0.028659 seconds
# PLANNING
# SolutionResult.kSolutionFound
# 0.085743 seconds
# finding_vertex POINT (-2 0) 0.0
# finding_vertex POINT (-1.25 0.75) 90.0
# found path endpoint hulls 36 5
# INITIALIZED ShapeBoat
# boats_S:(1, 12, 6), boats_U:(1, 11, 4)
# Number of decision vars 171
# 0.001718 seconds
# ADDING COSTS
# Number of costs 2
# 0.001056 seconds
# ADDING CONSTRAINTS
# Number of constraints 696
# 0.047130 seconds
# PLANNING
# SolutionResult.kSolutionFound
# 0.167985 seconds
# finding_vertex POINT (2.5 0) 0.0
# finding_vertex POINT (0 0.5) 180.0
# found path endpoint hulls 38 31
# INITIALIZED ShapeBoat
# boats_S:(1, 12, 6), boats_U:(1, 11, 4)
# Number of decision vars 193
# 0.002298 seconds
# ADDING COSTS
# Number of costs 2
# 0.001134 seconds
# ADDING CONSTRAINTS
# Number of constraints 846
# 0.059418 seconds
# PLANNING
# SolutionResult.kSolutionFound
# 0.251554 seconds
# finding_vertex POINT (-2 0) 0.0
# finding_vertex POINT (0 1) 0.0
# found path endpoint hulls 28 30
# INITIALIZED ShapeBoat
# boats_S:(1, 12, 6), boats_U:(1, 11, 4)
# Number of decision vars 171
# 0.001988 seconds
# ADDING COSTS
# Number of costs 2
# 0.001177 seconds
# ADDING CONSTRAINTS
# Number of constraints 674
# 0.047248 seconds
# PLANNING
# SolutionResult.kSolutionFound
# 0.206725 seconds
# finding_vertex POINT (-2.5 0) 0.0
# finding_vertex POINT (-1 0.5) 0.0
# found path endpoint hulls 12 30
# INITIALIZED ShapeBoat
# boats_S:(1, 12, 6), boats_U:(1, 11, 4)
# Number of decision vars 160
# 0.001711 seconds
# ADDING COSTS
# Number of costs 2
# 0.001038 seconds
# ADDING CONSTRAINTS
# Number of constraints 544
# 0.034873 seconds
# PLANNING
# SolutionResult.kSolutionFound
# 0.119789 seconds
# finding_vertex POINT (-1.5 0) 0.0
# finding_vertex POINT (0.5 0.5) 0.0
# found path endpoint hulls 29 31
# INITIALIZED ShapeBoat
# boats_S:(1, 12, 6), boats_U:(1, 11, 4)
# Number of decision vars 182
# 0.002036 seconds
# ADDING COSTS
# Number of costs 2
# 0.001079 seconds
# ADDING CONSTRAINTS
# Number of constraints 782
# 0.054575 seconds
# PLANNING
# SolutionResult.kSolutionFound
# 0.301676 seconds
# finding_vertex POINT (-2 0) 0.0
# finding_vertex POINT (0 0.5) 0.0
# found path endpoint hulls 34 38
# INITIALIZED ShapeBoat
# boats_S:(1, 12, 6), boats_U:(1, 11, 4)
# Number of decision vars 182
# 0.002140 seconds
# ADDING COSTS
# Number of costs 2
# 0.001331 seconds
# ADDING CONSTRAINTS
# Number of constraints 738
# 0.100931 seconds
# PLANNING
# SolutionResult.kSolutionFound
# 0.228082 seconds
# finding_vertex POINT (0 -0.5) 180.0
# finding_vertex POINT (0 1.5) 180.0
# found path endpoint hulls 31 32
# INITIALIZED ShapeBoat
# boats_S:(1, 12, 6), boats_U:(1, 11, 4)
# Number of decision vars 204
# 0.002571 seconds
# ADDING COSTS
# Number of costs 2
# 0.001116 seconds
# ADDING CONSTRAINTS
# Number of constraints 1020
# 0.090753 seconds
# PLANNING
# SolutionResult.kSolutionFound
# 0.235772 seconds
# finding_vertex POINT (-5 0) 0.0
# finding_vertex POINT (5 0) 0.0
# found path endpoint hulls 13 8
# INITIALIZED ShapeBoat_spline
# boats_S:(1, 12, 6), boats_U:(1, 11, 4)
# Number of decision vars 149
# 0.002701 seconds
# ADDING COSTS
# Number of costs 13
# 0.005765 seconds
# ADDING CONSTRAINTS
# Number of constraints 588
# 0.072148 seconds
# PLANNING
# SolutionResult.kSolutionFound
# 0.119212 seconds
#
# finding_vertex POINT (-5 0) 0.0
# finding_vertex POINT (5 0) 0.0
# found path endpoint hulls 13 8
# INITIALIZED ShapeBoat_spline
# boats_S:(1, 12, 6), boats_U:(1, 11, 4)
# Number of decision vars 116
# 0.000861 seconds
# ADDING COSTS
# Number of costs 13
# 0.004373 seconds
# ADDING CONSTRAINTS
# Number of constraints 242
# 0.065873 seconds
# PLANNING
# SolutionResult.kSolutionFound
# 0.072306 seconds
#
# Time Scaling target: 1.000000, result: 1.000000
# Time Scaling target: 1.197152, result: 1.200000
# finding_vertex POINT (-2 0) 0.0
# finding_vertex POINT (-1.25 0.75) 90.0
# found path endpoint hulls 36 5
# INITIALIZED ShapeBoat_spline
# boats_S:(1, 12, 6), boats_U:(1, 11, 4)
# Number of decision vars 171
# 0.001786 seconds
# ADDING COSTS
# Number of costs 13
# 0.005095 seconds
# ADDING CONSTRAINTS
# Number of constraints 1048
# 0.246372 seconds
# PLANNING
# SolutionResult.kSolutionFound
# 0.369294 seconds
#
# finding_vertex POINT (-2 0) 0.0
# finding_vertex POINT (-1.25 0.75) 90.0
# found path endpoint hulls 36 5
# INITIALIZED ShapeBoat_spline
# boats_S:(1, 12, 6), boats_U:(1, 11, 4)
# Number of decision vars 116
# 0.000825 seconds
# ADDING COSTS
# Number of costs 13
# 0.004536 seconds
# ADDING CONSTRAINTS
# Number of constraints 330
# 0.143488 seconds
# PLANNING
# SolutionResult.kSolutionFound
# 0.303888 seconds
#
# Time Scaling target: 1.000000, result: 1.000000
# Time Scaling target: 0.531137, result: 0.600000
# finding_vertex POINT (2.5 0) 0.0
# finding_vertex POINT (0 0.5) 180.0
# found path endpoint hulls 38 31
# INITIALIZED ShapeBoat_spline
# boats_S:(1, 12, 6), boats_U:(1, 11, 4)
# Number of decision vars 193
# 0.002314 seconds
# ADDING COSTS
# Number of costs 13
# 0.004811 seconds
# ADDING CONSTRAINTS
# Number of constraints 1298
# 0.253486 seconds
# PLANNING
# SolutionResult.kSolutionFound
# 0.170853 seconds
#
# finding_vertex POINT (2.5 0) 0.0
# finding_vertex POINT (0 0.5) 180.0
# found path endpoint hulls 38 31
# INITIALIZED ShapeBoat_spline
# boats_S:(1, 12, 6), boats_U:(1, 11, 4)
# Number of decision vars 116
# 0.000831 seconds
# ADDING COSTS
# Number of costs 13
# 0.004355 seconds
# ADDING CONSTRAINTS
# Number of constraints 396
# 0.132634 seconds
# PLANNING
# SolutionResult.kSolutionFound
# 0.371072 seconds
#
# Time Scaling target: 1.000000, result: 1.000000
# Time Scaling target: 0.766560, result: 0.800000
# finding_vertex POINT (-2 0) 0.0
# finding_vertex POINT (0 1) 0.0
# found path endpoint hulls 28 30
# INITIALIZED ShapeBoat_spline
# boats_S:(1, 12, 6), boats_U:(1, 11, 4)
# Number of decision vars 171
# 0.003807 seconds
# ADDING COSTS
# Number of costs 13
# 0.004643 seconds
# ADDING CONSTRAINTS
# Number of constraints 1006
# 0.207355 seconds
# PLANNING
# SolutionResult.kSolutionFound
# 0.215866 seconds
#
# finding_vertex POINT (-2 0) 0.0
# finding_vertex POINT (0 1) 0.0
# found path endpoint hulls 28 30
# INITIALIZED ShapeBoat_spline
# boats_S:(1, 12, 6), boats_U:(1, 11, 4)
# Number of decision vars 116
# 0.001010 seconds
# ADDING COSTS
# Number of costs 13
# 0.004915 seconds
# ADDING CONSTRAINTS
# Number of constraints 330
# 0.179150 seconds
# PLANNING
# SolutionResult.kSolutionFound
# 0.193938 seconds
#
# Time Scaling target: 1.000000, result: 1.000000
# Time Scaling target: 0.688248, result: 0.800000
# finding_vertex POINT (-2.5 0) 0.0
# finding_vertex POINT (-1 0.5) 0.0
# found path endpoint hulls 12 30
# INITIALIZED ShapeBoat_spline
# boats_S:(1, 12, 6), boats_U:(1, 11, 4)
# Number of decision vars 160
# 0.001631 seconds
# ADDING COSTS
# Number of costs 13
# 0.004762 seconds
# ADDING CONSTRAINTS
# Number of constraints 776
# 0.128356 seconds
# PLANNING
# SolutionResult.kSolutionFound
# 0.278834 seconds
#
# finding_vertex POINT (-2.5 0) 0.0
# finding_vertex POINT (-1 0.5) 0.0
# found path endpoint hulls 12 30
# INITIALIZED ShapeBoat_spline
# boats_S:(1, 12, 6), boats_U:(1, 11, 4)
# Number of decision vars 116
# 0.000897 seconds
# ADDING COSTS
# Number of costs 13
# 0.004354 seconds
# ADDING CONSTRAINTS
# Number of constraints 286
# 0.083870 seconds
# PLANNING
# SolutionResult.kSolutionFound
# 0.103017 seconds
#
# Time Scaling target: 1.000000, result: 1.000000
# Time Scaling target: 0.476092, result: 0.600000
# finding_vertex POINT (-1.5 0) 0.0
# finding_vertex POINT (0.5 0.5) 0.0
# found path endpoint hulls 29 31
# INITIALIZED ShapeBoat_spline
# boats_S:(1, 12, 6), boats_U:(1, 11, 4)
# Number of decision vars 182
# 0.003135 seconds
# ADDING COSTS
# Number of costs 13
# 0.007102 seconds
# ADDING CONSTRAINTS
# Number of constraints 1194
# 0.278269 seconds
# PLANNING
# SolutionResult.kSolutionFound
# 0.403594 seconds
#
# finding_vertex POINT (-1.5 0) 0.0
# finding_vertex POINT (0.5 0.5) 0.0
# found path endpoint hulls 29 31
# INITIALIZED ShapeBoat_spline
# boats_S:(1, 12, 6), boats_U:(1, 11, 4)
# Number of decision vars 116
# 0.000933 seconds
# ADDING COSTS
# Number of costs 13
# 0.004474 seconds
# ADDING CONSTRAINTS
# Number of constraints 418
# 0.128522 seconds
# PLANNING
# SolutionResult.kSolutionFound
# 0.077440 seconds
#
# Time Scaling target: 1.000000, result: 1.000000
# Time Scaling target: 0.922761, result: 1.000000
# finding_vertex POINT (-2 0) 0.0
# finding_vertex POINT (0 0.5) 0.0
# found path endpoint hulls 34 38
# INITIALIZED ShapeBoat_spline
# boats_S:(1, 12, 6), boats_U:(1, 11, 4)
# Number of decision vars 182
# 0.002242 seconds
# ADDING COSTS
# Number of costs 13
# 0.008993 seconds
# ADDING CONSTRAINTS
# Number of constraints 1110
# 0.274871 seconds
# PLANNING
# SolutionResult.kSolutionFound
# 0.165090 seconds
#
# finding_vertex POINT (-2 0) 0.0
# finding_vertex POINT (0 0.5) 0.0
# found path endpoint hulls 34 38
# INITIALIZED ShapeBoat_spline
# boats_S:(1, 12, 6), boats_U:(1, 11, 4)
# Number of decision vars 116
# 0.000869 seconds
# ADDING COSTS
# Number of costs 13
# 0.004535 seconds
# ADDING CONSTRAINTS
# Number of constraints 396
# 0.119780 seconds
# PLANNING
# SolutionResult.kSolutionFound
# 0.117915 seconds
#
# Time Scaling target: 1.000000, result: 1.000000
# Time Scaling target: 0.836983, result: 1.000000
# finding_vertex POINT (0 -0.5) 180.0
# finding_vertex POINT (0 1.5) 180.0
# found path endpoint hulls 31 32
# INITIALIZED ShapeBoat_spline
# boats_S:(1, 12, 6), boats_U:(1, 11, 4)
# Number of decision vars 204
# 0.002760 seconds
# ADDING COSTS
# Number of costs 13
# 0.004562 seconds
# ADDING CONSTRAINTS
# Number of constraints 1612
# 0.347045 seconds
# PLANNING
# SolutionResult.kSolutionFound
# 0.200243 seconds
#
# finding_vertex POINT (0 -0.5) 180.0
# finding_vertex POINT (0 1.5) 180.0
# found path endpoint hulls 31 32
# INITIALIZED ShapeBoat_spline
# boats_S:(1, 12, 6), boats_U:(1, 11, 4)
# Number of decision vars 116
# 0.000971 seconds
# ADDING COSTS
# Number of costs 13
# 0.004337 seconds
# ADDING CONSTRAINTS
# Number of constraints 594
# 0.169265 seconds
# PLANNING
# SolutionResult.kSolutionFound
# 0.092496 seconds
#
# Time Scaling target: 1.000000, result: 1.000000
# Time Scaling target: 1.456622, result: 1.600000

# %%
write_experiment(results, 'result2')
