# %%
# %load_ext autoreload
# %autoreload 2
import timeit
import pickle
import numpy as np
import matplotlib.pyplot as plt
from shape import Shape, Block, plot_hulls
from convex_hulls_graph import HullGraph
from shapely.geometry import Point
from shape_boat import ShapeBoat, ShapeBoat_spline, check_vertex_constraints
from multiboat_trajectory_optimization.boat_models import Boat, TwoInputBoat
from multiboat_trajectory_optimization.trajectory_planner import BoatConfigurationPlanning

# %% [markdown]
# ### Composing Shapes from Blocks

# %%
shape_a = Shape([Block(-0.75,0.5,90),Block(0,0.25,0),Block(1,0.25,0),Block(1.75,.5,90)])
shape_b = Block(0,0.25)

#shape_a.polygon

# %%
#shape_b.plot(union=False)

# %%
#shape_a.plot(union=False)

# %% [markdown]
# ### Partitioning of convex hulls around shape

# %%
hulls = shape_a.partition_around(buffered=False)
#plot_hulls(hulls, text=False)

# %% [markdown]
# ### C-Space of a given obstacle b

# %%
ab = shape_a.c_space(shape_b)
#ab.plot(union=True)

# %% [markdown]
# ### Finding Convex Hull of C-Space

# %%
hulls = ab.partition_around(buffered=False)
ab.plot_polygons(hulls)

# %%
# %load_ext autoreload
# %autoreload 2

g = HullGraph(hulls)
g.draw_graph()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Trajectory Planning

# %%
def experiment(boat_shape, obstacle_shape, xy0, xyN, margin=0, boat_type=ShapeBoat):
    x0 = np.zeros((1, Boat.num_states))
    xN = np.zeros((1, Boat.num_states))
    x0[0, :2] = xy0
    xN[0, :2] = xyN
    boat = boat_type(boat_shape, obstacle_shape)
    boat.set_end_points(x0, xN)
    planner = BoatConfigurationPlanning(boat)
    boats_S, boats_U, time_array, mp, result, solve_time = planner.compute_trajectory(0., 10, x0, xN, time_cost=False, input_cost=True, slack=0, N=100)
    return boat, boats_S, boats_U

def experiment_spline(boat_shape, obstacle_shape, xy0, xyN, N=10, margin=0, boat_type=ShapeBoat_spline):
    x0 = np.zeros((1, Boat.num_states))
    xN = np.zeros((1, Boat.num_states))
    x0[0, :2] = xy0
    xN[0, :2] = xyN
    boat = boat_type(boat_shape, obstacle_shape)
    boat.set_end_points(x0, xN)
    planner = BoatConfigurationPlanning(boat)
    boats_S, boats_U, time_array, mp, result, solve_time = planner.compute_spline_trajectory(0., 20, x0, xN, input_cost=True, slack=0, N=N)
    return boat, boats_S, boats_U

def write_experiment(boat, boats_S, boats_U, label):
    with open('results/path_'+label+'.pickle', 'wb') as f:
        pickle.dump([boat,boats_S,boats_U], f)

# %% [markdown]
# ### Shape B around Shape A

# %%
boat, boats_S, boats_U = experiment(shape_b, shape_a, [5,0], [-2.5,.51])
# Out:
# 1
# INITIALIZED 1 ShapeBoat boats
# boats_S:(1, 101, 4), boats_U:(1, 100, 2), time_array:(101,)
# Number of decision vars 604
# 0.006915 seconds
# ADDING COSTS
# 0.028942 seconds
# ADDING CONSTRAINTS
# True
# 0.248982 seconds
# PLANNING
# SolutionResult.kSolutionFound
# 1.529423 seconds

# %%
plot_hulls(boat.hulls, (boats_S[0,:,0], boats_S[0,:,1]), text=False)
print boat.hull_path
# Out:
# [0, 2, 3]

# %% [markdown]
# ### Shape B around shape B

# %%
boat, boats_S, boats_U = experiment(shape_b, shape_b, [0,3], [0,-3])
write_experiment(boat, boats_S, boats_U, 'avoid')
# Out:
# 1
# INITIALIZED 1 ShapeBoat boats
# boats_S:(1, 101, 4), boats_U:(1, 100, 2), time_array:(101,)
# Number of decision vars 604
# 0.002735 seconds
# ADDING COSTS
# 0.013012 seconds
# ADDING CONSTRAINTS
# True
# 0.253831 seconds
# PLANNING
# SolutionResult.kSolutionFound
# 2.435190 seconds

# %%
plot_hulls(boat.hulls, (boats_S[0,:,0], boats_S[0,:,1]), text=False)
print boat.hull_path
# Out:
# [1, 0, 4]

# %% [markdown]
# ### Shape B latch to Shape B

# %%
boat, boats_S, boats_U = experiment(shape_b, shape_b, [1,3], [0,0.51])
write_experiment(boat, boats_S, boats_U, 'latch')
# Out:
# 1
# INITIALIZED 1 ShapeBoat boats
# boats_S:(1, 101, 4), boats_U:(1, 100, 2), time_array:(101,)
# Number of decision vars 604
# 0.003489 seconds
# ADDING COSTS
# 0.014576 seconds
# ADDING CONSTRAINTS
# True
# 0.191763 seconds
# PLANNING
# SolutionResult.kSolutionFound
# 0.026942 seconds

# %%
plot_hulls(boat.hulls, (boats_S[0,:,0], boats_S[0,:,1]), text=False)
print boat.hull_path
# Out:
# [1]

# %%
boat, boats_S, boats_U = experiment_spline(shape_b, shape_b, [3,0], [-3,0])
# Out:
# 1
# INITIALIZED 1 ShapeBoat_spline boats
# boats_S:(1, 11, 4), boats_U:(1, 10, 2), time_array:(11,)
# Number of decision vars 64
# 0.000936 seconds
# 2.0
# [[ 0.5  0.5  0. ]
#  [-1.   1.   0. ]
#  [ 0.5 -1.   0.5]]
# [[0. 0. 0.]
#  [0. 0. 0.]
#  [0. 0. 1.]]
# ADDING COSTS
# 0.009602 seconds
# ADDING CONSTRAINTS
# True
# 0.010289 seconds
# PLANNING
# SolutionResult.kSolutionFound
# 0.020643 seconds

# %%
plot_hulls(boat.hulls, (boats_S[0,:,0], boats_S[0,:,1]), text=False)

# %%
def B_i_k(x, i, k):
    if k==0:
        return 1. if i<=x<i+1 else 0.
    
    return ((x-i)*B_i_k(x, i, k-1) + ((i+k+1)-x)*B_i_k(x, i+1, k-1))/k
    
def knots_to_trajectory(boats_S, N, order=3):
    boats_S_sample = np.zeros((boats_S.shape[0],boats_S.shape[1]+2*(order-1),boats_S.shape[2]))
    boats_S_sample[:,order:-order] = boats_S[:,1:-1]
    boats_S_sample[:,:order] = boats_S[:,0,:]
    boats_S_sample[:,-order:] = boats_S[:,-1,:]
        
    shape = boats_S_sample.shape
    num_knots = shape[1]
    
    dN = (N-1)/float(num_knots-3)

    assert dN.is_integer(), "%f is not an integer" % dN
    
    new_boats_S = np.zeros((shape[0],N,shape[2]))

    #b_x = np.zeros(N)
        
    for b in range(shape[0]):
        for x in range(0,N):            
            for i in range(int(x/dN), min(int(x/dN)+4,num_knots)):
                new_boats_S[b,x] += B_i_k(float(x)/dN, i-3, 3)*boats_S_sample[b,i]
                #b_x[x] += B_i_k(float(x)/dN, i-3, 3)

    #print b_x
    return new_boats_S


#boats_S_new = knots_to_trajectory(boats_S, 105)

# %%
boat, boats_S, boats_U = experiment_spline(shape_b, shape_b, [-3.3,-1], [3,2.5], N=2)
#boats_S = np.array([[[0.,1.],[0.1,1.5],[0.5,2.0],[0.6,-1.],[-1., -2.], [-3.,-3.]]])
boats_S_new = knots_to_trajectory(boats_S, 41)

plt.figure(figsize=(10,10))
plot_hulls(boat.hulls, (boats_S[0,:,0], boats_S[0,:,1]), text=False)
plt.plot(boats_S_new[0,:,0], boats_S_new[0,:,1], color='red', linewidth='4')
plt.show()
# Out:
# 1
# INITIALIZED 1 ShapeBoat_spline boats
# boats_S:(1, 3, 4), boats_U:(1, 2, 2), time_array:(3,)
# Number of decision vars 16
# 0.001676 seconds
# 10.0
# [[ 0.5  0.5  0. ]
#  [-1.   1.   0. ]
#  [ 0.5 -1.   0.5]]
# [[0 0 0]
#  [0 0 0]
#  [0 0 4]]
# ADDING COSTS
# 0.001748 seconds
# ADDING CONSTRAINTS
# True
# 0.004834 seconds
# PLANNING
# SolutionResult.kSolutionFound
# 0.028870 seconds

# %%
B_i_k(1,2,0)
# Out:
# 0.0

# %%
print boats_S
# Out:
# [[[ 3.          0.          0.          0.          0.
#     0.        ]
#   [ 0.5927347  -2.34273466  0.          0.          0.
#     0.        ]
#   [ 1.0000002  -0.50000026  0.          0.          0.
#     0.        ]
#   [ 1.40416414 -1.90371582  0.          0.          0.
#     0.        ]
#   [ 1.00264605 -0.50354269  0.          0.          0.
#     0.        ]
#   [ 1.399448   -1.898218    0.          0.          0.
#     0.        ]
#   [ 1.00462061 -0.50618403  0.          0.          0.
#     0.        ]
#   [ 1.39583363 -1.89400233  0.          0.          0.
#     0.        ]
#   [ 1.00622929 -0.50832856  0.          0.          0.
#     0.        ]
#   [ 1.39645229 -1.89413367  0.          0.          0.
#     0.        ]
#   [ 1.00756116 -0.5100992   0.          0.          0.
#     0.        ]
#   [ 1.39800326 -1.89528589  0.          0.          0.
#     0.        ]
#   [ 1.00865596 -0.51155272  0.          0.          0.
#     0.        ]
#   [ 1.39901815 -1.89597708  0.          0.          0.
#     0.        ]
#   [ 1.00953718 -0.51272264  0.          0.          0.
#     0.        ]
#   [ 1.39971782 -1.89641986  0.          0.          0.
#     0.        ]
#   [ 1.0102228  -0.51363332  0.          0.          0.
#     0.        ]
#   [ 1.40040447 -1.89691117  0.          0.          0.
#     0.        ]
#   [ 1.01072809 -0.51430424  0.          0.          0.
#     0.        ]
#   [ 1.40139445 -1.89776386  0.          0.          0.
#     0.        ]
#   [ 1.01106905 -0.51475415  0.          0.          0.
#     0.        ]
#   [ 1.40257935 -1.89886729  0.          0.          0.
#     0.        ]
#   [ 1.01126871 -0.5150078   0.          0.          0.
#     0.        ]
#   [ 1.40095186 -1.89721284  0.          0.          0.
#     0.        ]
#   [ 4.47213595 -4.47213595  0.          0.          0.
#     0.        ]
#   [-3.          0.          0.          0.          0.
#     0.        ]]]
